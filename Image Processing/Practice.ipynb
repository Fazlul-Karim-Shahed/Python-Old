# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
import pandas

# %%
img = io.imread('./cell.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
randomImg = np.random.random([3, 3])
plt.imshow(randomImg)

# %%
plt.imshow(img[1:100, 1:200])
