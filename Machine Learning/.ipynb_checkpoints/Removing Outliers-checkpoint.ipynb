# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
ds = pandas.read_csv('Datasheets/Maternal Health Risk Data Set.csv')

# %%
ds.shape
# Out:
# (1014, 7)

# %%
ds.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
ds.SystolicBP
# Out:
# 0       130
# 1       140
# 2        90
# 3       140
# 4       120
#        ...
# 1009    120
# 1010    120
# 1011     85
# 1012    120
# 1013    120
# Name: SystolicBP, Length: 1014, dtype: int64

# %%
sb.histplot(ds.SystolicBP, kde=True)
# Out:
# <AxesSubplot:xlabel='SystolicBP', ylabel='Count'>

# %%
mean = ds.SystolicBP.mean()

# %%
std = ds.SystolicBP.std()
