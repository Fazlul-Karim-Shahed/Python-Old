# %%
import pandas
import numpy
from matplotlib import pyplot as plt
from tensorflow import keras
# from sklearn.model_selection import train_test_split

# %%
ds = pandas.read_csv('../DataSheets/Social_Network_Ads.csv')
ds.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
ds = ds.drop(['User ID', 'Gender'], axis=1)
ds
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
plt.scatter(ds.EstimatedSalary, ds.Purchased)
plt.show()

# %%
ds['Age'] = ds["Age"]/ds.Age.max()
ds['EstimatedSalary'] = ds["EstimatedSalary"]/ds.EstimatedSalary.max()

# %%
# x_train, x_test, y_train, y_test = train_test_split(ds[['Age', 'EstimatedSalary']], test_size=.2, random_state=25)

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(ds[['Age', 'EstimatedSalary']], ds['Purchased'], epochs=1000)
# Out:
# Epoch 1/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9041 - accuracy: 0.3575
# Epoch 2/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8951 - accuracy: 0.3575
# Epoch 3/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8858 - accuracy: 0.3575
# Epoch 4/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8772 - accuracy: 0.3575
# Epoch 5/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8685 - accuracy: 0.3575
# Epoch 6/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8599 - accuracy: 0.3575
# Epoch 7/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8519 - accuracy: 0.3575
# Epoch 8/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8435 - accuracy: 0.3575
# Epoch 9/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8356 - accuracy: 0.3575
# Epoch 10/1000
# ...

# %%
model.evaluate(ds[['Age', 'EstimatedSalary']], ds['Purchased'])
# Out:
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4447 - accuracy: 0.8175
# [0.4447042942047119, 0.8174999952316284]

# %% [markdown]
# Without Tensorflow

# %%
def sigmoid(x):
    pass

# %%
def myLoss(y_predicted, y_truth):
     pass

# %%
def gradientDecent(age, estimatedSalary, purchased, epoch):
    w1 = w1 = 1
    b = 0
    for i in range(epoch):
        weighted_sum = w1*age + w1*estimatedSalary + b
        y_predicted = sigmoid(weighted_sum)
        loss = myLoss(y_predicted, purchased)
